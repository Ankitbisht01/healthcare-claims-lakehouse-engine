# %%
# %sql
CREATE CATALOG IF NOT EXISTS healthcare_lakehouse
  MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragezvwlz32iiqygi.dfs.core.windows.net/7405619245559486/healthcare_lakehouse';
USE CATALOG healthcare_lakehouse;

CREATE SCHEMA IF NOT EXISTS bronze;
USE SCHEMA bronze;
